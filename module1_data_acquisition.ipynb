# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# Load main dataset
df = pd.read_csv('data/diabetic_data.csv')

# Load mapping file
df_mapping = pd.read_csv('data/IDS_mapping.csv')

print("Datasets loaded successfully!")
print(f"Main dataset shape: {df.shape}")
# Out:
# Datasets loaded successfully!
# Main dataset shape: (101766, 50)

# %%
# First 5 rows
df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital payer_code         medical_specialty  num_lab_procedures  \
# ...

# %%
# All column names
print(df.columns.tolist())
# Out:
# ['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 'time_in_hospital', 'payer_code', 'medical_specialty', 'num_lab_procedures', 'num_procedures', 'num_medications', 'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1', 'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone', 'tolazamide', 'examide', 'citoglipton', 'insulin', 'glyburide-metformin', 'glipizide-metformin', 'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted']

# %%
# Data types and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101766 entries, 0 to 101765
# Data columns (total 50 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   encounter_id              101766 non-null  int64
#  1   patient_nbr               101766 non-null  int64
#  2   race                      101766 non-null  object
#  3   gender                    101766 non-null  object
#  4   age                       101766 non-null  object
#  5   weight                    101766 non-null  object
#  6   admission_type_id         101766 non-null  int64
#  7   discharge_disposition_id  101766 non-null  int64
#  8   admission_source_id       101766 non-null  int64
#  9   time_in_hospital          101766 non-null  int64
#  10  payer_code                101766 non-null  object
#  11  medical_specialty         101766 non-null  object
#  12  num_lab_procedures        101766 non-null  int64
# ...

# %%
# How many patients in each readmission category
print(df['readmitted'].value_counts())
print("\nPercentage:")
print(df['readmitted'].value_counts(normalize=True) * 100)
# Out:
# readmitted
# NO     54864
# >30    35545
# <30    11357
# Name: count, dtype: int64
#
# Percentage:
# readmitted
# NO     53.911916
# >30    34.928169
# <30    11.159916
# Name: proportion, dtype: float64

# %%
# Statistical summary of numerical columns
df.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
# Check for '?' which represents missing values in this dataset
missing = (df == '?').sum()
print(missing[missing > 0])
# Out:
# race                  2273
# weight               98569
# payer_code           40256
# medical_specialty    49949
# diag_1                  21
# diag_2                 358
# diag_3                1423
# dtype: int64

# %%
# A patient can have multiple encounters
# Let's check how many unique patients we have
print(f"Total encounters: {df.shape[0]}")
print(f"Unique patients: {df['patient_nbr'].nunique()}")
print(f"Patients with multiple visits: {df.shape[0] - df['patient_nbr'].nunique()}")
# Out:
# Total encounters: 101766
# Unique patients: 71518
# Patients with multiple visits: 30248

# %%
print("=" * 50)
print("MODULE 1 - DATA ACQUISITION SUMMARY")
print("=" * 50)
print(f"Total Records       : {df.shape[0]}")
print(f"Total Features      : {df.shape[1]}")
print(f"Unique Patients     : {df['patient_nbr'].nunique()}")
print(f"Target Column       : readmitted")
print(f"Target Distribution : {df['readmitted'].value_counts().to_dict()}")
print(f"Hidden Missing (??) : weight(97%), payer_code(40%), medical_specialty(49%)")
print(f"Columns to Drop     : encounter_id, patient_nbr, weight, payer_code")
print("=" * 50)
print("Ready for Module 2 - Data Cleaning & Preprocessing!")
# Out:
# ...
# MODULE 1 - DATA ACQUISITION SUMMARY
# ...
# Total Records       : 101766
# Total Features      : 50
# Unique Patients     : 71518
# Target Column       : readmitted
# Target Distribution : {'NO': 54864, '>30': 35545, '<30': 11357}
# Hidden Missing (??) : weight(97%), payer_code(40%), medical_specialty(49%)
# Columns to Drop     : encounter_id, patient_nbr, weight, payer_code
# ...
# Ready for Module 2 - Data Cleaning & Preprocessing!
